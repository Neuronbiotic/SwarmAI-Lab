# %% [markdown]
# # SwarmAI-Lab experiment notebook
# Use this template to explore new update rules or visualize consensus trajectories.

# %%
from swarmlab.sim.consensus import run_consensus
from swarmlab.utils.seed import set_seed

set_seed(123)
result = run_consensus(num_agents=4, initial_states=[0, 0.5, 1, 1], rule="average", steps=6)
result.history[-1]
